# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
image = Image.open("calib_image.tif")

# %%
plt.figure(figsize=(16, 10))
plt.imshow(image, cmap="gray")
plt.axvline(600)
plt.axvline(1200)

# %%
(10.8-3.9)/600
# Out:
# 0.0115

# %%
plt.figure(figsize=(16, 10))
plt.imshow(image, cmap="gray")
plt.axvline(695)
plt.axvline(1103)

# %%
(9.7-5)/(1103-695)
# Out:
# 0.011519607843137254

# %% [markdown]
# The value of pixel per cm is **0.0115**.

# %%
fps = 1000
pixels = 0.0115
g_calc = 0.08676337293846638
g_calc*pixels*fps**2
# Out:
# 805.0

# %%
image.size[0]*pixels, image.size[1]*pixels
# Out:
# (14.719999999999999, 9.2)
