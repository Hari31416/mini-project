# %%
import re
import pandas as pd
import glob

# %%
files = glob.glob("results/*/info.txt")

# %%
with open(files[-1], "r") as f:
    lines = f.readlines()
    info_lines = []
    i=0
    for line in lines:
        if "###" in line:
            info_lines.append(line.strip())
            print(i, line.strip())
            i+=1
# Out:
# 0 ### ref.tif
# 1 ### First Frame ID: 017
# 2 ### Last Frame ID: 161
# 3 ### Contact Frame ID: 068
# 4 ### Leave Frame ID: 107
# 5 ### Angle: 24.5
# 6 ### TOTAL FRAMES: 171
# 7 ### NONE FRAMES: 15
# 8 ### UNREALISTIC FRAMES: 6
# 9 ### PASSTHROUGH: 0
# 10 ### H: 165.9
# 11 ### ANGLE: 23.5
# 12 ### VELOCITY: 5.45
# 13 ### X VELOCITY: -0.09
# 14 ### Y VELOCITY: 5.45
# 15 ### ANGLE: 33.18
# 16 ### VELOCITY: 4.81
# 17 ### X VELOCITY: 4.03
# 18 ### Y VELOCITY: -2.63
# 19 ### H: 161.0
# 20 ### ANGLE: 22.82
# 21 ### VELOCITY: 4.86
# 22 ### X VELOCITY: -0.14
# 23 ### Y VELOCITY: 4.86
# 24 ### ANGLE: 30.07
# 25 ### VELOCITY: 6.27
# 26 ### X VELOCITY: 5.43
# 27 ### Y VELOCITY: -3.14
# 28 ### H: 167.0
# 29 ### ANGLE: 25.03
# 30 ### VELOCITY: 5.35
# 31 ### X VELOCITY: -0.05
# 32 ### Y VELOCITY: 5.35
# 33 ### g: 980.86
# 34 ### ANGLE: 27.68
# 35 ### VELOCITY: 5.28
# 36 ### X VELOCITY: 4.67
# 37 ### Y VELOCITY: -2.45
# 38 ### g: 982.96

# %%
info_dict_smooth = {
    "ID": 0,
    "Contact_Frame": 3,
    "Leave_Frame": 4,
    "Angle_Thin_Film": 5,
    "Total_Frames": 6,
    "Passthrough": 9,
    "H": 10,
    "Angle_of_Drop_with_Normal": 11,
    "Velocity_at_Contact_Frame": 12,
    "X_Velocity_at_Contact_Frame": 13,
    "Y_Velocity_at_Contact_Frame": 14,
    "Angle_at_Leave_Frame": 15,
    "Velocity_at_Leave_Frame": 16,
    "X_Velocity_at_Leave_Frame": 17,
    "Y_Velocity_at_Leave_Frame": 18,
}

info_dict_raw = {
    "ID": 0,
    "Contact_Frame": 3,
    "Leave_Frame": 4,
    "Angle_Thin_Film": 5,
    "Total_Frames": 6,
    "Passthrough": 9,
    "H": 19,
    "Angle_of_Drop_with_Normal": 20,
    "Velocity_at_Contact_Frame": 21,
    "X_Velocity_at_Contact_Frame": 22,
    "Y_Velocity_at_Contact_Frame": 23,
    "Angle_at_Leave_Frame": 24,
    "Velocity_at_Leave_Frame": 25,
    "X_Velocity_at_Leave_Frame": 26,
    "Y_Velocity_at_Leave_Frame": 27,
    "H_C": 28,
    "Angle_at_Contact_Frame_C": 29,
    "Velocity_at_Contact_Frame_C": 30,
    "X_Velocity_at_Contact_Frame_C": 31,
    "Y_Velocity_at_Contact_Frame_C": 32,
    "g_in_Region_I": 33,
    "Angle_at_Leave_Frame_C": 34,
    "Velocity_at_Leave_Frame_C": 35,
    "X_Velocity_at_Leave_Frame_C": 36,
    "Y_Velocity_at_Leave_Frame_C": 37,
    "g_in_Region_III": 38,
}

# %%
info_dict = {
    "ID": [],
    "Contact_Frame": [],
    "Leave_Frame": [],
    "Angle_Thin_Film": [],
    "Total_Frames": [],
    "Passthrough": [],
    "H": [],
    "Angle_of_Drop_with_Normal": [],
    "Velocity_at_Contact_Frame": [],
    "X_Velocity_at_Contact_Frame": [],
    "Y_Velocity_at_Contact_Frame": [],
    "Angle_at_Leave_Frame": [],
    "Velocity_at_Leave_Frame": [],
    "X_Velocity_at_Leave_Frame": [],
    "Y_Velocity_at_Leave_Frame": [],
}

# %%
for file in files:
    with open(file, "r") as f:
        lines = f.readlines()
        i=0
        for line in lines:
            if "###" in line:
                for key, value in info_dict_smooth.items():
                    information = line.strip().split(":")[-1].strip()
                    if value==i:
                        info_dict[key].append(information)
                i+=1

# %%
smooth_df = pd.DataFrame(info_dict)
smooth_df["ID"] = smooth_df["ID"].apply(lambda x: x[3:].split(".")[0])

# %%
smooth_df.head().T
# Out:
#                                  0           1           2           3  \
# ID                              h1   h10_short   h11_short   h12_short
# Contact_Frame                  073         067         072         020
# Leave_Frame                    085         085         092         042
# Angle_Thin_Film               21.5        24.5        27.5        27.5
# Total_Frames                   219         178         166         100
# Passthrough                      0           0           0           0
# H                             79.4       169.5       174.8        68.6
# Angle_of_Drop_with_Normal    32.48       21.28       23.52       26.08
# Velocity_at_Contact_Frame     3.45        5.27        5.52        5.57
# X_Velocity_at_Contact_Frame   0.66        -0.3       -0.38       -0.14
# Y_Velocity_at_Contact_Frame   3.38        5.26        5.51        5.57
# Angle_at_Leave_Frame         -7.96       31.71       24.43        8.94
# Velocity_at_Leave_Frame       3.52        4.87         4.4        5.39
# X_Velocity_at_Leave_Frame     3.48        4.14        4.01        5.33
# Y_Velocity_at_Leave_Frame     0.49       -2.56       -1.82       -0.84
#
#                                       4
# ID                            h13_short
# Contact_Frame                       077
# Leave_Frame                         097
# Angle_Thin_Film                    27.5
# Total_Frames                        171
# Passthrough                           0
# H                                 206.3
# Angle_of_Drop_with_Normal         27.11
# Velocity_at_Contact_Frame          5.88
# X_Velocity_at_Contact_Frame       -0.04
# Y_Velocity_at_Contact_Frame        5.88
# Angle_at_Leave_Frame              21.17
# Velocity_at_Leave_Frame            6.18
# X_Velocity_at_Leave_Frame          5.76
# Y_Velocity_at_Leave_Frame         -2.23

# %%
info_dict = {
    "ID": [],
    "Contact_Frame": [],
    "Leave_Frame": [],
    "Angle_Thin_Film": [],
    "Total_Frames": [],
    "Passthrough": [],
    "H": [],
    "Angle_of_Drop_with_Normal": [],
    "Velocity_at_Contact_Frame": [],
    "X_Velocity_at_Contact_Frame": [],
    "Y_Velocity_at_Contact_Frame": [],
    "Angle_at_Leave_Frame": [],
    "Velocity_at_Leave_Frame": [],
    "X_Velocity_at_Leave_Frame": [],
    "Y_Velocity_at_Leave_Frame": [],
    "H_C": [], 
    "Angle_at_Contact_Frame_C": [],
    "Velocity_at_Contact_Frame_C": [],
    "X_Velocity_at_Contact_Frame_C": [],
    "Y_Velocity_at_Contact_Frame_C": [],
    "g_in_Region_I": [],
    "Angle_at_Leave_Frame_C": [],
    "Velocity_at_Leave_Frame_C": [],
    "X_Velocity_at_Leave_Frame_C": [],
    "Y_Velocity_at_Leave_Frame_C": [],
    "g_in_Region_III": [],
}
for file in files:
    with open(file, "r") as f:
        lines = f.readlines()
        i=0
        for line in lines:
            if "###" in line:
                for key, value in info_dict_raw.items():
                    information = line.strip().split(":")[-1].strip()
                    if value==i:
                        info_dict[key].append(information)
                i+=1

# %%
raw_df = pd.DataFrame(info_dict)
raw_df["ID"] = raw_df["ID"].apply(lambda x: x[3:].split(".")[0])

# %%
raw_df.head().T
# Out:
#                                     0           1           2           3  \
# ID                                 h1   h10_short   h11_short   h12_short
# Contact_Frame                     073         067         072         020
# Leave_Frame                       085         085         092         042
# Angle_Thin_Film                  21.5        24.5        27.5        27.5
# Total_Frames                      219         178         166         100
# Passthrough                         0           0           0           0
# H                                74.0       166.0       170.0        66.0
# Angle_of_Drop_with_Normal       19.01       22.86        27.5       25.95
# Velocity_at_Contact_Frame        3.29         5.0         5.0        5.29
# X_Velocity_at_Contact_Frame     -0.14       -0.14         0.0       -0.14
# Y_Velocity_at_Contact_Frame      3.29         5.0         5.0        5.29
# Angle_at_Leave_Frame            14.93       28.93       21.32       17.65
# Velocity_at_Leave_Frame          6.65         6.2        6.29         6.6
# X_Velocity_at_Leave_Frame        6.43        5.43        5.86        6.29
# Y_Velocity_at_Leave_Frame       -1.71        -3.0       -2.29        -2.0
# H_C                              75.0       166.0       170.0        66.0
# Angle_at_Contact_Frame_C        22.07       25.06       28.11       29.43
# Velocity_at_Contact_Frame_C      3.58        5.37        5.42         5.6
# X_Velocity_at_Contact_Frame_C   -0.04       -0.05       -0.06       -0.19
# Y_Velocity_at_Contact_Frame_C    3.58        5.37        5.42        5.59
# g_in_Region_I                  974.97      992.87      988.47      876.31
# Angle_at_Leave_Frame_C          -7.05        28.3       -15.0      -61.17
# Velocity_at_Leave_Frame_C        2.42        5.32        3.28        1.69
# X_Velocity_at_Leave_Frame_C      2.41        4.69        3.16        0.82
# Y_Velocity_at_Leave_Frame_C       0.3       -2.52        0.85        1.48
# g_in_Region_III                693.71      978.16      727.63      719.31
#
#                                         4
# ID                              h13_short
# Contact_Frame                         077
# Leave_Frame                           097
# Angle_Thin_Film                      27.5
# Total_Frames                          171
# Passthrough                             0
# H                                   204.0
# Angle_of_Drop_with_Normal           24.64
# Velocity_at_Contact_Frame            5.72
# X_Velocity_at_Contact_Frame         -0.29
# Y_Velocity_at_Contact_Frame          5.71
# Angle_at_Leave_Frame                 25.6
# Velocity_at_Leave_Frame               7.6
# X_Velocity_at_Leave_Frame            6.86
# Y_Velocity_at_Leave_Frame           -3.29
# H_C                                 203.0
# Angle_at_Contact_Frame_C            27.84
# Velocity_at_Contact_Frame_C          5.94
# X_Velocity_at_Contact_Frame_C       -0.04
# Y_Velocity_at_Contact_Frame_C        5.94
# g_in_Region_I                     1001.35
# Angle_at_Leave_Frame_C              21.49
# Velocity_at_Leave_Frame_C            6.01
# X_Velocity_at_Leave_Frame_C          5.59
# Y_Velocity_at_Leave_Frame_C          -2.2
# g_in_Region_III                   1014.36

# %%
def get_num(value):
    reg = re.compile(r'\d+')
    try:
        num = reg.findall(value)[0]
    except:
        return str(99)
    if len(str(num)) == 1:
        num = "0"+num
    return num

# %%
raw_df["Temp_Col"] = raw_df["ID"].apply(get_num)
smooth_df["Temp_Col"] = smooth_df["ID"].apply(get_num)

# %%
raw_df = raw_df.sort_values(by="Temp_Col").reset_index(drop=True)
smooth_df = smooth_df.sort_values(by="Temp_Col").reset_index(drop=True)

# %%
smooth_df.drop(columns=["Temp_Col"], inplace=True)
raw_df.drop(columns=["Temp_Col"], inplace=True)

# %%
smooth_df.to_csv("results/info_on_smooth_data.csv", index=False)
raw_df.to_csv("results/info_on_raw_data.csv", index=False)

# %%
raw_df.head().T
# Out:
#                                     0        1        2        3       4
# ID                                 h1   h1_try       h2       h3      h4
# Contact_Frame                     073      073      094      263     116
# Leave_Frame                       085      085      113      285     136
# Angle_Thin_Film                  21.5     21.5       27       27    24.5
# Total_Frames                      219      219      300      370     282
# Passthrough                         0        0        0        1       0
# H                                74.0     70.0     81.0     86.0    99.0
# Angle_of_Drop_with_Normal       19.01     19.4    24.71     27.0   22.38
# Velocity_at_Contact_Frame        3.29     3.15     3.57     3.57    3.86
# X_Velocity_at_Contact_Frame     -0.14    -0.14    -0.14      0.0   -0.14
# Y_Velocity_at_Contact_Frame      3.29     3.14     3.57     3.57    3.86
# Angle_at_Leave_Frame            14.93    13.74    -45.0     -0.0   28.61
# Velocity_at_Leave_Frame          6.65     6.62     2.22     2.57    5.37
# X_Velocity_at_Leave_Frame        6.43     6.43     1.57     2.57    4.71
# Y_Velocity_at_Leave_Frame       -1.71    -1.57     1.57      0.0   -2.57
# H_C                              75.0     71.0     80.0     86.0    99.0
# Angle_at_Contact_Frame_C        22.07    22.56    27.47    27.32   24.53
# Velocity_at_Contact_Frame_C      3.58     3.48     3.76     3.89    4.13
# X_Velocity_at_Contact_Frame_C   -0.04    -0.03    -0.03    -0.02    -0.0
# Y_Velocity_at_Contact_Frame_C    3.58     3.48     3.76     3.89    4.13
# g_in_Region_I                  974.97   971.86  1018.24  1011.22  985.38
# Angle_at_Leave_Frame_C          -7.05   -10.81     2.79   -49.41   21.41
# Velocity_at_Leave_Frame_C        2.42     2.45      2.2     3.41    4.21
# X_Velocity_at_Leave_Frame_C      2.41     2.41     2.19     2.22    3.92
# Y_Velocity_at_Leave_Frame_C       0.3     0.46    -0.11     2.59   -1.54
# g_in_Region_III                693.71    628.0   477.65  -975.16  972.16
