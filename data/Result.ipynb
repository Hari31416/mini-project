# %%
import re
import pandas as pd
import glob

# %%
files = glob.glob("results/*/info.txt")

# %%
with open(files[1], "r") as f:
    lines = f.readlines()
    info_lines = []
    i=0
    for line in lines:
        if "###" in line:
            info_lines.append(line.strip())
            print(i, line.strip())
            i+=1
# Out:
# 0 ### h10_short.tif
# 1 ### First Frame ID: 007.jpg
# 2 ### Last Frame ID: 168.jpg
# 3 ### Contact Frame ID: 067.jpg
# 4 ### Leave Frame ID: 085.jpg
# 5 ### Angle: 24.5
# 6 ### TOTAL FRAMES: 178
# 7 ### NONE FRAMES: 22
# 8 ### UNREALISTIC FRAMES: 6
# 9 ### ANGLE: 21.28
# 10 ### VELOCITY: 5.27
# 11 ### X VELOCITY: -0.3
# 12 ### Y VELOCITY: 5.26
# 13 ### ANGLE: -54.29
# 14 ### VELOCITY: 3.29
# 15 ### X VELOCITY: 1.92
# 16 ### Y VELOCITY: 2.67
# 17 ### ANGLE: 22.86
# 18 ### VELOCITY: 5.0
# 19 ### X VELOCITY: -0.14
# 20 ### Y VELOCITY: 5.0
# 21 ### ANGLE: -53.75
# 22 ### VELOCITY: 2.66
# 23 ### X VELOCITY: 1.57
# 24 ### Y VELOCITY: 2.14

# %%
info_dict_smooth = {
    "ID": 0,
    "Contact_Frame": 3,
    "Leave_Frame": 4,
    "Angle_Thin_Film": 5,
    "Total_Frames": 6,
    "Angle_of_Drop_with_Normal": 9,
    "Velocity_at_Contact_Frame": 10,
    "X_Velocity_at_Contact_Frame": 11,
    "Y_Velocity_at_Contact_Frame": 12,
    "Angle_at_Leave_Frame": 13,
    "Velocity_at_Leave_Frame": 14,
    "X_Velocity_at_Leave_Frame": 15,
    "Y_Velocity_at_Leave_Frame": 16,
}

info_dict_raw = {
    "ID": 0,
    "Contact_Frame": 3,
    "Leave_Frame": 4,
    "Angle_Thin_Film": 5,
    "Total_Frames": 6,
    "Angle_of_Drop_with_Normal": 17,
    "Velocity_at_Contact_Frame": 18,
    "X_Velocity_at_Contact_Frame": 19,
    "Y_Velocity_at_Contact_Frame": 20,
    "Angle_at_Leave_Frame": 21,
    "Velocity_at_Leave_Frame": 22,
    "X_Velocity_at_Leave_Frame": 23,
    "Y_Velocity_at_Leave_Frame": 24,
}

# %%
info_dict = {
    "ID": [],
    "Contact_Frame": [],
    "Leave_Frame": [],
    "Angle_Thin_Film": [],
    "Total_Frames": [],
    "Angle_of_Drop_with_Normal": [],
    "Velocity_at_Contact_Frame": [],
    "X_Velocity_at_Contact_Frame": [],
    "Y_Velocity_at_Contact_Frame": [],
    "Angle_at_Leave_Frame": [],
    "Velocity_at_Leave_Frame": [],
    "X_Velocity_at_Leave_Frame": [],
    "Y_Velocity_at_Leave_Frame": [],
}

# %%
for file in files:
    with open(file, "r") as f:
        lines = f.readlines()
        i=0
        for line in lines:
            if "###" in line:
                for key, value in info_dict_raw.items():
                    information = line.strip().split(":")[-1].strip()
                    if value==i:
                        info_dict[key].append(information)
                i+=1

# %%
raw_df = pd.DataFrame(info_dict)
raw_df["ID"] = raw_df["ID"].apply(lambda x: x[3:].split(".")[0])

# %%
raw_df.head().T
# Out:
#                                    0           1           2           3  \
# ID                                h1   h10_short   h11_short   h12_short
# Contact_Frame                073.jpg     067.jpg     072.jpg     020.jpg
# Leave_Frame                  085.jpg     085.jpg     092.jpg     042.jpg
# Angle_Thin_Film                 21.5        24.5        27.5        27.5
# Total_Frames                     219         178         166         100
# Angle_of_Drop_with_Normal      19.01       22.86        27.5       25.95
# Velocity_at_Contact_Frame       3.29         5.0         5.0        5.29
# X_Velocity_at_Contact_Frame    -0.14       -0.14         0.0       -0.14
# Y_Velocity_at_Contact_Frame     3.29         5.0         5.0        5.29
# Angle_at_Leave_Frame            1000      -53.75       -45.0      -33.69
# Velocity_at_Leave_Frame         1000        2.66        2.83        3.09
# X_Velocity_at_Leave_Frame       1000        1.57         2.0        2.57
# Y_Velocity_at_Leave_Frame       1000        2.14         2.0        1.71
#
#                                       4
# ID                            h13_short
# Contact_Frame                   077.jpg
# Leave_Frame                     097.jpg
# Angle_Thin_Film                    27.5
# Total_Frames                        171
# Angle_of_Drop_with_Normal         24.64
# Velocity_at_Contact_Frame          5.72
# X_Velocity_at_Contact_Frame       -0.29
# Y_Velocity_at_Contact_Frame        5.71
# Angle_at_Leave_Frame             -43.03
# Velocity_at_Leave_Frame            2.93
# X_Velocity_at_Leave_Frame          2.14
# Y_Velocity_at_Leave_Frame           2.0

# %%
info_dict = {
    "ID": [],
    "Contact_Frame": [],
    "Leave_Frame": [],
    "Angle_Thin_Film": [],
    "Total_Frames": [],
    "Angle_of_Drop_with_Normal": [],
    "Velocity_at_Contact_Frame": [],
    "X_Velocity_at_Contact_Frame": [],
    "Y_Velocity_at_Contact_Frame": [],
    "Angle_at_Leave_Frame": [],
    "Velocity_at_Leave_Frame": [],
    "X_Velocity_at_Leave_Frame": [],
    "Y_Velocity_at_Leave_Frame": [],
}

for file in files:
    with open(file, "r") as f:
        lines = f.readlines()
        i=0
        for line in lines:
            if "###" in line:
                for key, value in info_dict_smooth.items():
                    information = line.strip().split(":")[-1].strip()
                    if value==i:
                        info_dict[key].append(information)
                i+=1

# %%
smooth_df = pd.DataFrame(info_dict)
smooth_df["ID"] = smooth_df["ID"].apply(lambda x: x[3:].split(".")[0])

# %%
smooth_df.head().T
# Out:
#                                    0           1           2           3  \
# ID                                h1   h10_short   h11_short   h12_short
# Contact_Frame                073.jpg     067.jpg     072.jpg     020.jpg
# Leave_Frame                  085.jpg     085.jpg     092.jpg     042.jpg
# Angle_Thin_Film                 21.5        24.5        27.5        27.5
# Total_Frames                     219         178         166         100
# Angle_of_Drop_with_Normal      32.48       21.28       23.52       26.08
# Velocity_at_Contact_Frame       3.45        5.27        5.52        5.57
# X_Velocity_at_Contact_Frame     0.66        -0.3       -0.38       -0.14
# Y_Velocity_at_Contact_Frame     3.38        5.26        5.51        5.57
# Angle_at_Leave_Frame          -50.46      -54.29      -47.01      -39.95
# Velocity_at_Leave_Frame         3.16        3.29         4.1        3.28
# X_Velocity_at_Leave_Frame       2.01        1.92         2.8        2.51
# Y_Velocity_at_Leave_Frame       2.44        2.67         3.0        2.11
#
#                                       4
# ID                            h13_short
# Contact_Frame                   077.jpg
# Leave_Frame                     097.jpg
# Angle_Thin_Film                    27.5
# Total_Frames                        171
# Angle_of_Drop_with_Normal         27.11
# Velocity_at_Contact_Frame          5.88
# X_Velocity_at_Contact_Frame       -0.04
# Y_Velocity_at_Contact_Frame        5.88
# Angle_at_Leave_Frame             -45.74
# Velocity_at_Leave_Frame            3.45
# X_Velocity_at_Leave_Frame          2.41
# Y_Velocity_at_Leave_Frame          2.47

# %%
def get_num(value):
    reg = re.compile(r'\d+')
    try:
        num = reg.findall(value)[0]
    except:
        return str(99)
    if len(str(num)) == 1:
        num = "0"+num
    return num

# %%
raw_df["Temp_Col"] = raw_df["ID"].apply(get_num)
smooth_df["Temp_Col"] = smooth_df["ID"].apply(get_num)

# %%
raw_df = raw_df.sort_values(by="Temp_Col").reset_index(drop=True)
smooth_df = smooth_df.sort_values(by="Temp_Col").reset_index(drop=True)

# %%
smooth_df.drop(columns=["Temp_Col"], inplace=True)
raw_df.drop(columns=["Temp_Col"], inplace=True)

# %%
smooth_df.to_csv("results/info_on_smooth_data.csv", index=False)
raw_df.to_csv("results/info_on_raw_data.csv", index=False)

# %%
smooth_df.head().T
# Out:
#                                    0        1        2        3        4
# ID                                h1   h1_try       h2       h3       h4
# Contact_Frame                073.jpg  073.jpg  094.jpg  263.jpg  116.jpg
# Leave_Frame                  085.jpg  085.jpg  113.jpg  285.jpg  136.jpg
# Angle_Thin_Film                 21.5       22       27       27     24.5
# Total_Frames                     219      219      300      370      282
# Angle_of_Drop_with_Normal      32.48    32.98    26.94    27.33    17.54
# Velocity_at_Contact_Frame       3.45     3.45     3.76     3.95     3.83
# X_Velocity_at_Contact_Frame     0.66     0.66     -0.0     0.02    -0.46
# Y_Velocity_at_Contact_Frame     3.38     3.38     3.76     3.95      3.8
# Angle_at_Leave_Frame          -50.46   -50.46   -57.03   -58.12   -43.65
# Velocity_at_Leave_Frame         3.16     3.16     2.54     2.72     2.87
# X_Velocity_at_Leave_Frame       2.01     2.01     1.38     1.44     2.08
# Y_Velocity_at_Leave_Frame       2.44     2.44     2.13     2.31     1.98
