# %%
import re
import pandas as pd
import glob

# %%
files = glob.glob("results/*/info.txt")

# %%
with open(files[-1], "r") as f:
    lines = f.readlines()
    info_lines = []
    i=0
    for line in lines:
        if "###" in line:
            info_lines.append(line.strip())
            print(i, line.strip())
            i+=1
# Out:
# 0 ### ref.tif
# 1 ### First Frame ID: 017.jpg
# 2 ### Last Frame ID: 161.jpg
# 3 ### Contact Frame ID: 068.jpg
# 4 ### Leave Frame ID: 090.jpg
# 5 ### Angle: 24.5
# 6 ### TOTAL FRAMES: 171
# 7 ### NONE FRAMES: 15
# 8 ### UNREALISTIC FRAMES: 6
# 9 ### PASSTHROUGH: 0
# 10 ### H: 165.9
# 11 ### ANGLE: 23.5
# 12 ### VELOCITY: 5.45
# 13 ### X VELOCITY: -0.09
# 14 ### Y VELOCITY: 5.45
# 15 ### ANGLE: -26.46
# 16 ### VELOCITY: 2.81
# 17 ### X VELOCITY: 2.51
# 18 ### Y VELOCITY: 1.25
# 19 ### H: 161.0
# 20 ### ANGLE: 22.82
# 21 ### VELOCITY: 4.86
# 22 ### X VELOCITY: -0.14
# 23 ### Y VELOCITY: 4.86
# 24 ### ANGLE: -26.57
# 25 ### VELOCITY: 2.87
# 26 ### X VELOCITY: 2.57
# 27 ### Y VELOCITY: 1.29

# %%
info_dict_smooth = {
    "ID": 0,
    "Contact_Frame": 3,
    "Leave_Frame": 4,
    "Angle_Thin_Film": 5,
    "Total_Frames": 6,
    "Passthrough": 9,
    "H": 10,
    "Angle_of_Drop_with_Normal": 11,
    "Velocity_at_Contact_Frame": 12,
    "X_Velocity_at_Contact_Frame": 13,
    "Y_Velocity_at_Contact_Frame": 14,
    "Angle_at_Leave_Frame": 15,
    "Velocity_at_Leave_Frame": 16,
    "X_Velocity_at_Leave_Frame": 17,
    "Y_Velocity_at_Leave_Frame": 18,
}

info_dict_raw = {
    "ID": 0,
    "Contact_Frame": 3,
    "Leave_Frame": 4,
    "Angle_Thin_Film": 5,
    "Total_Frames": 6,
    "Passthrough": 9,
    "H": 19,
    "Angle_of_Drop_with_Normal": 20,
    "Velocity_at_Contact_Frame": 21,
    "X_Velocity_at_Contact_Frame": 22,
    "Y_Velocity_at_Contact_Frame": 23,
    "Angle_at_Leave_Frame": 24,
    "Velocity_at_Leave_Frame": 25,
    "X_Velocity_at_Leave_Frame": 26,
    "Y_Velocity_at_Leave_Frame": 27,
}

# %%
info_dict = {
    "ID": [],
    "Contact_Frame": [],
    "Leave_Frame": [],
    "Angle_Thin_Film": [],
    "Total_Frames": [],
    "Passthrough": [],
    "H": [],
    "Angle_of_Drop_with_Normal": [],
    "Velocity_at_Contact_Frame": [],
    "X_Velocity_at_Contact_Frame": [],
    "Y_Velocity_at_Contact_Frame": [],
    "Angle_at_Leave_Frame": [],
    "Velocity_at_Leave_Frame": [],
    "X_Velocity_at_Leave_Frame": [],
    "Y_Velocity_at_Leave_Frame": [],
}

# %%
for file in files:
    with open(file, "r") as f:
        lines = f.readlines()
        i=0
        for line in lines:
            if "###" in line:
                for key, value in info_dict_smooth.items():
                    information = line.strip().split(":")[-1].strip()
                    if value==i:
                        info_dict[key].append(information)
                i+=1

# %%
smooth_df = pd.DataFrame(info_dict)
smooth_df["ID"] = smooth_df["ID"].apply(lambda x: x[3:].split(".")[0])

# %%
smooth_df.head().T
# Out:
#                                    0           1           2           3  \
# ID                                h1   h10_short   h11_short   h12_short
# Contact_Frame                073.jpg     067.jpg     072.jpg     020.jpg
# Leave_Frame                  085.jpg     085.jpg     092.jpg     042.jpg
# Angle_Thin_Film                 21.5        24.5        27.5        27.5
# Total_Frames                     219         178         166         100
# Passthrough                        0           0           0           0
# H                               79.4       169.5       174.8        54.4
# Angle_of_Drop_with_Normal      32.48       21.28       23.52       26.08
# Velocity_at_Contact_Frame       3.45        5.27        5.52        5.57
# X_Velocity_at_Contact_Frame     0.66        -0.3       -0.38       -0.14
# Y_Velocity_at_Contact_Frame     3.38        5.26        5.51        5.57
# Angle_at_Leave_Frame          -30.77        0.02        0.41        4.29
# Velocity_at_Leave_Frame         3.17        3.09        3.65        4.21
# X_Velocity_at_Leave_Frame       2.73        3.09        3.65         4.2
# Y_Velocity_at_Leave_Frame       1.62        -0.0       -0.03       -0.31
#
#                                       4
# ID                            h13_short
# Contact_Frame                   077.jpg
# Leave_Frame                     097.jpg
# Angle_Thin_Film                    27.5
# Total_Frames                        171
# Passthrough                           0
# H                                 206.3
# Angle_of_Drop_with_Normal         27.11
# Velocity_at_Contact_Frame          5.88
# X_Velocity_at_Contact_Frame       -0.04
# Y_Velocity_at_Contact_Frame        5.88
# Angle_at_Leave_Frame               3.74
# Velocity_at_Leave_Frame            4.19
# X_Velocity_at_Leave_Frame          4.18
# Y_Velocity_at_Leave_Frame         -0.27

# %%
info_dict = {
    "ID": [],
    "Contact_Frame": [],
    "Leave_Frame": [],
    "Angle_Thin_Film": [],
    "Total_Frames": [],
    "Passthrough": [],
    "H": [],
    "Angle_of_Drop_with_Normal": [],
    "Velocity_at_Contact_Frame": [],
    "X_Velocity_at_Contact_Frame": [],
    "Y_Velocity_at_Contact_Frame": [],
    "Angle_at_Leave_Frame": [],
    "Velocity_at_Leave_Frame": [],
    "X_Velocity_at_Leave_Frame": [],
    "Y_Velocity_at_Leave_Frame": [],
}
for file in files:
    with open(file, "r") as f:
        lines = f.readlines()
        i=0
        for line in lines:
            if "###" in line:
                for key, value in info_dict_raw.items():
                    information = line.strip().split(":")[-1].strip()
                    if value==i:
                        info_dict[key].append(information)
                i+=1

# %%
raw_df = pd.DataFrame(info_dict)
raw_df["ID"] = raw_df["ID"].apply(lambda x: x[3:].split(".")[0])

# %%
raw_df.head().T
# Out:
#                                    0           1           2           3  \
# ID                                h1   h10_short   h11_short   h12_short
# Contact_Frame                073.jpg     067.jpg     072.jpg     020.jpg
# Leave_Frame                  085.jpg     085.jpg     092.jpg     042.jpg
# Angle_Thin_Film                 21.5        24.5        27.5        27.5
# Total_Frames                     219         178         166         100
# Passthrough                        0           0           0           0
# H                               74.0       166.0       170.0        52.0
# Angle_of_Drop_with_Normal      19.01       22.86        27.5       25.95
# Velocity_at_Contact_Frame       3.29         5.0         5.0        5.29
# X_Velocity_at_Contact_Frame    -0.14       -0.14         0.0       -0.14
# Y_Velocity_at_Contact_Frame     3.29         5.0         5.0        5.29
# Angle_at_Leave_Frame            1000       -2.73       -10.3        4.24
# Velocity_at_Leave_Frame         1000         3.0        9.58        3.87
# X_Velocity_at_Leave_Frame       1000         3.0        9.43        3.86
# Y_Velocity_at_Leave_Frame       1000        0.14        1.71       -0.29
#
#                                       4
# ID                            h13_short
# Contact_Frame                   077.jpg
# Leave_Frame                     097.jpg
# Angle_Thin_Film                    27.5
# Total_Frames                        171
# Passthrough                           0
# H                                 204.0
# Angle_of_Drop_with_Normal         24.64
# Velocity_at_Contact_Frame          5.72
# X_Velocity_at_Contact_Frame       -0.29
# Y_Velocity_at_Contact_Frame        5.71
# Angle_at_Leave_Frame              -2.12
# Velocity_at_Leave_Frame            3.86
# X_Velocity_at_Leave_Frame          3.86
# Y_Velocity_at_Leave_Frame          0.14

# %%
def get_num(value):
    reg = re.compile(r'\d+')
    try:
        num = reg.findall(value)[0]
    except:
        return str(99)
    if len(str(num)) == 1:
        num = "0"+num
    return num

# %%
raw_df["Temp_Col"] = raw_df["ID"].apply(get_num)
smooth_df["Temp_Col"] = smooth_df["ID"].apply(get_num)

# %%
raw_df = raw_df.sort_values(by="Temp_Col").reset_index(drop=True)
smooth_df = smooth_df.sort_values(by="Temp_Col").reset_index(drop=True)

# %%
smooth_df.drop(columns=["Temp_Col"], inplace=True)
raw_df.drop(columns=["Temp_Col"], inplace=True)

# %%
smooth_df.to_csv("results/info_on_smooth_data.csv", index=False)
raw_df.to_csv("results/info_on_raw_data.csv", index=False)

# %%
smooth_df.head().T
# Out:
#                                    0        1        2        3        4
# ID                                h1   h1_try       h2       h3       h4
# Contact_Frame                073.jpg  073.jpg  094.jpg  263.jpg  116.jpg
# Leave_Frame                  085.jpg  085.jpg  113.jpg  285.jpg  136.jpg
# Angle_Thin_Film                 21.5     21.5       27       27     24.5
# Total_Frames                     219      219      300      370      282
# Passthrough                        0        0        0        0        0
# H                               79.4     79.4     88.1     89.0     99.1
# Angle_of_Drop_with_Normal      32.48    32.48    26.94    27.33    17.54
# Velocity_at_Contact_Frame       3.45     3.45     3.76     3.95     3.83
# X_Velocity_at_Contact_Frame     0.66     0.66     -0.0     0.02    -0.46
# Y_Velocity_at_Contact_Frame     3.38     3.38     3.76     3.95      3.8
# Angle_at_Leave_Frame          -30.77   -30.77    -6.02    -6.96     2.73
# Velocity_at_Leave_Frame         3.17     3.17     2.89     2.35     2.65
# X_Velocity_at_Leave_Frame       2.73     2.73     2.87     2.33     2.65
# Y_Velocity_at_Leave_Frame       1.62     1.62      0.3     0.28    -0.13
