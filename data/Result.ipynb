# %%
import re
import pandas as pd
import glob

# %%
files = glob.glob("results/*/info.txt")

# %%
with open(files[-1], "r") as f:
    lines = f.readlines()
    info_lines = []
    i=0
    for line in lines:
        if "###" in line:
            info_lines.append(line.strip())
            print(i, line.strip())
            i+=1
# Out:
# 0 ### h5_short.tif
# 1 ### First Frame ID: 010.jpg
# 2 ### Last Frame ID: 170.jpg
# 3 ### Contact Frame ID: 059.jpg
# 4 ### Leave Frame ID: 077.jpg
# 5 ### Angle: 24.5
# 6 ### TOTAL FRAMES: 180
# 7 ### NONE FRAMES: 23
# 8 ### UNREALISTIC FRAMES: 8
# 9 ### PASSTHROUGH: 0
# 10 ### H: 110.3
# 11 ### ANGLE: 19.67
# 12 ### VELOCITY: 4.04
# 13 ### X VELOCITY: -0.34
# 14 ### Y VELOCITY: 4.03
# 15 ### ANGLE: -56.0
# 16 ### VELOCITY: 2.78
# 17 ### X VELOCITY: 1.56
# 18 ### Y VELOCITY: 2.31
# 19 ### H: 109.0
# 20 ### ANGLE: 24.5
# 21 ### VELOCITY: 4.0
# 22 ### X VELOCITY: 0.0
# 23 ### Y VELOCITY: 4.0
# 24 ### ANGLE: -59.04
# 25 ### VELOCITY: 2.5
# 26 ### X VELOCITY: 1.29
# 27 ### Y VELOCITY: 2.14

# %%
info_dict_smooth = {
    "ID": 0,
    "Contact_Frame": 3,
    "Leave_Frame": 4,
    "Angle_Thin_Film": 5,
    "Total_Frames": 6,
    "Passthrough": 9,
    "H": 10,
    "Angle_of_Drop_with_Normal": 11,
    "Velocity_at_Contact_Frame": 12,
    "X_Velocity_at_Contact_Frame": 13,
    "Y_Velocity_at_Contact_Frame": 14,
    "Angle_at_Leave_Frame": 15,
    "Velocity_at_Leave_Frame": 16,
    "X_Velocity_at_Leave_Frame": 17,
    "Y_Velocity_at_Leave_Frame": 18,
}

info_dict_raw = {
    "ID": 0,
    "Contact_Frame": 3,
    "Leave_Frame": 4,
    "Angle_Thin_Film": 5,
    "Total_Frames": 6,
    "Passthrough": 9,
    "H": 19,
    "Angle_of_Drop_with_Normal": 20,
    "Velocity_at_Contact_Frame": 21,
    "X_Velocity_at_Contact_Frame": 22,
    "Y_Velocity_at_Contact_Frame": 23,
    "Angle_at_Leave_Frame": 24,
    "Velocity_at_Leave_Frame": 25,
    "X_Velocity_at_Leave_Frame": 26,
    "Y_Velocity_at_Leave_Frame": 27,
}

# %%
info_dict = {
    "ID": [],
    "Contact_Frame": [],
    "Leave_Frame": [],
    "Angle_Thin_Film": [],
    "Total_Frames": [],
    "Passthrough": [],
    "H": [],
    "Angle_of_Drop_with_Normal": [],
    "Velocity_at_Contact_Frame": [],
    "X_Velocity_at_Contact_Frame": [],
    "Y_Velocity_at_Contact_Frame": [],
    "Angle_at_Leave_Frame": [],
    "Velocity_at_Leave_Frame": [],
    "X_Velocity_at_Leave_Frame": [],
    "Y_Velocity_at_Leave_Frame": [],
}

# %%
for file in files:
    with open(file, "r") as f:
        lines = f.readlines()
        i=0
        for line in lines:
            if "###" in line:
                for key, value in info_dict_smooth.items():
                    information = line.strip().split(":")[-1].strip()
                    if value==i:
                        info_dict[key].append(information)
                i+=1

# %%
for key in info_dict:
    print(len(info_dict[key]))
# Out:
# 28
# 28
# 28
# 28
# 28
# 28
# 28
# 28
# 28
# 28
# 28
# 28
# 28
# 28
# 28

# %%
smooth_df = pd.DataFrame(info_dict)
smooth_df["ID"] = smooth_df["ID"].apply(lambda x: x[3:].split(".")[0])

# %%
smooth_df.head().T
# Out:
#                                    0           1        2        3        4
# ID                                h3   h23_short       h6       h4      h24
# Contact_Frame                263.jpg     035.jpg  062.jpg  116.jpg  026.jpg
# Leave_Frame                  285.jpg     040.jpg  082.jpg  136.jpg  029.jpg
# Angle_Thin_Film                   27        18.5     24.5     24.5     20.5
# Total_Frames                     370          56      191      282       48
# Passthrough                        0           1        0        0        1
# H                               89.0       391.8    122.3     99.1    486.4
# Angle_of_Drop_with_Normal      27.33       17.55    21.48    17.54    16.71
# Velocity_at_Contact_Frame       3.95       12.75     4.42     3.83     7.37
# X_Velocity_at_Contact_Frame     0.02       -0.21    -0.23    -0.46    -0.49
# Y_Velocity_at_Contact_Frame     3.95       12.74     4.41      3.8     7.35
# Angle_at_Leave_Frame          -58.12      -89.01   -43.49   -43.65   -84.29
# Velocity_at_Leave_Frame         2.72       12.68     2.67     2.87    10.85
# X_Velocity_at_Leave_Frame       1.44        0.22     1.93     2.08     1.08
# Y_Velocity_at_Leave_Frame       2.31       12.68     1.83     1.98     10.8

# %%
info_dict = {
    "ID": [],
    "Contact_Frame": [],
    "Leave_Frame": [],
    "Angle_Thin_Film": [],
    "Total_Frames": [],
    "Passthrough": [],
    "H": [],
    "Angle_of_Drop_with_Normal": [],
    "Velocity_at_Contact_Frame": [],
    "X_Velocity_at_Contact_Frame": [],
    "Y_Velocity_at_Contact_Frame": [],
    "Angle_at_Leave_Frame": [],
    "Velocity_at_Leave_Frame": [],
    "X_Velocity_at_Leave_Frame": [],
    "Y_Velocity_at_Leave_Frame": [],
}
for file in files:
    with open(file, "r") as f:
        lines = f.readlines()
        i=0
        for line in lines:
            if "###" in line:
                for key, value in info_dict_raw.items():
                    information = line.strip().split(":")[-1].strip()
                    if value==i:
                        info_dict[key].append(information)
                i+=1

# %%
raw_df = pd.DataFrame(info_dict)
raw_df["ID"] = raw_df["ID"].apply(lambda x: x[3:].split(".")[0])

# %%
raw_df.head().T
# Out:
#                                    0           1        2        3        4
# ID                                h3   h23_short       h6       h4      h24
# Contact_Frame                263.jpg     035.jpg  062.jpg  116.jpg  026.jpg
# Leave_Frame                  285.jpg     040.jpg  082.jpg  136.jpg  029.jpg
# Angle_Thin_Film                   27        18.5     24.5     24.5     20.5
# Total_Frames                     370          56      191      282       48
# Passthrough                        0           1        0        0        1
# H                               86.0       393.0    120.0     99.0    492.0
# Angle_of_Drop_with_Normal       27.0       17.86    22.59    22.38    18.45
# Velocity_at_Contact_Frame       3.57       12.86     4.29     3.86     8.01
# X_Velocity_at_Contact_Frame      0.0       -0.14    -0.14    -0.14    -0.29
# Y_Velocity_at_Contact_Frame     3.57       12.86     4.29     3.86      8.0
# Angle_at_Leave_Frame          -48.81       89.35   -40.24   -18.43    88.09
# Velocity_at_Leave_Frame         1.52       12.57     2.43     6.78     8.58
# X_Velocity_at_Leave_Frame        1.0       -0.14     1.86     6.43    -0.29
# Y_Velocity_at_Leave_Frame       1.14       12.57     1.57     2.14     8.57

# %%
def get_num(value):
    reg = re.compile(r'\d+')
    try:
        num = reg.findall(value)[0]
    except:
        return str(99)
    if len(str(num)) == 1:
        num = "0"+num
    return num

# %%
raw_df["Temp_Col"] = raw_df["ID"].apply(get_num)
smooth_df["Temp_Col"] = smooth_df["ID"].apply(get_num)

# %%
raw_df = raw_df.sort_values(by="Temp_Col").reset_index(drop=True)
smooth_df = smooth_df.sort_values(by="Temp_Col").reset_index(drop=True)

# %%
smooth_df.drop(columns=["Temp_Col"], inplace=True)
raw_df.drop(columns=["Temp_Col"], inplace=True)

# %%
smooth_df.to_csv("results/info_on_smooth_data.csv", index=False)
raw_df.to_csv("results/info_on_raw_data.csv", index=False)

# %%
smooth_df.head().T
# Out:
#                                    0        1        2        3        4
# ID                            h1_try       h1       h2       h3       h4
# Contact_Frame                073.jpg  073.jpg  094.jpg  263.jpg  116.jpg
# Leave_Frame                  085.jpg  085.jpg  113.jpg  285.jpg  136.jpg
# Angle_Thin_Film                   22     21.5       27       27     24.5
# Total_Frames                     219      219      300      370      282
# Passthrough                        0        0        0        0        0
# H                               79.4     79.4     88.1     89.0     99.1
# Angle_of_Drop_with_Normal      32.98    32.48    26.94    27.33    17.54
# Velocity_at_Contact_Frame       3.45     3.45     3.76     3.95     3.83
# X_Velocity_at_Contact_Frame     0.66     0.66     -0.0     0.02    -0.46
# Y_Velocity_at_Contact_Frame     3.38     3.38     3.76     3.95      3.8
# Angle_at_Leave_Frame          -50.46   -50.46   -57.03   -58.12   -43.65
# Velocity_at_Leave_Frame         3.16     3.16     2.54     2.72     2.87
# X_Velocity_at_Leave_Frame       2.01     2.01     1.38     1.44     2.08
# Y_Velocity_at_Leave_Frame       2.44     2.44     2.13     2.31     1.98
