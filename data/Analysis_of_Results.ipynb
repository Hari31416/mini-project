# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# from plotly.offline import init_notebook_mode
import seaborn as sns
# import cufflinks as cf
# init_notebook_mode(connected=True)
# cf.go_offline()
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Loading The CSV Files

# %%
smooth_df = pd.read_csv("results/info_on_smooth_data.csv")
raw_df = pd.read_csv("results/info_on_raw_data.csv")

# %% [markdown]
# # Analysis of Results

# %% [markdown]
# ## Results Using the Smoothed Data

# %%
smooth_df = smooth_df[:-1]
raw_df = raw_df[:-1]

# %%
smooth_df.T
# Out:
#                                   0        1        2        3        4   \
# ID                            h1_try       h1       h2       h3       h4
# Contact_Frame                073.jpg  073.jpg  094.jpg  263.jpg  116.jpg
# Leave_Frame                  085.jpg  085.jpg  113.jpg  285.jpg  136.jpg
# Angle_Thin_Film                 22.0     21.5     27.0     27.0     24.5
# Total_Frames                     219      219      300      370      282
# Passthrough                        0        0        0        0        0
# H                               79.4     79.4     88.1     89.0     99.1
# Angle_of_Drop_with_Normal      32.98    32.48    26.94    27.33    17.54
# Velocity_at_Contact_Frame       3.45     3.45     3.76     3.95     3.83
# X_Velocity_at_Contact_Frame     0.66     0.66     -0.0     0.02    -0.46
# Y_Velocity_at_Contact_Frame     3.38     3.38     3.76     3.95      3.8
# Angle_at_Leave_Frame          -50.46   -50.46   -57.03   -58.12   -43.65
# Velocity_at_Leave_Frame         3.16     3.16     2.54     2.72     2.87
# X_Velocity_at_Leave_Frame       2.01     2.01     1.38     1.44     2.08
# Y_Velocity_at_Leave_Frame       2.44     2.44     2.13     2.31     1.98
#
#                                     5        6          7        8   \
# ID                            h5_short       h6   h7_short       h7
# Contact_Frame                  059.jpg  062.jpg    059.jpg  059.jpg
# Leave_Frame                    077.jpg  082.jpg    077.jpg  079.jpg
# Angle_Thin_Film                   24.5     24.5       25.0     25.0
# Total_Frames                       180      191        180      273
# Passthrough                          0        0          0        0
# H                                110.3    122.3      125.8    125.7
# Angle_of_Drop_with_Normal        19.67    21.48      23.17    21.24
# Velocity_at_Contact_Frame         4.04     4.42       4.45     4.44
# X_Velocity_at_Contact_Frame      -0.34    -0.23      -0.14    -0.29
# Y_Velocity_at_Contact_Frame       4.03     4.41       4.45     4.43
# Angle_at_Leave_Frame             -56.0   -43.49     -53.12   -36.17
# Velocity_at_Leave_Frame           2.78     2.67       2.65     2.49
# X_Velocity_at_Leave_Frame         1.56     1.93       1.59     2.01
# Y_Velocity_at_Leave_Frame         2.31     1.83       2.12     1.47
#
#                                     9   ...          17          18  \
# ID                            h8_short  ...   h16_short   h17_short
# Contact_Frame                  062.jpg  ...     078.jpg     080.jpg
# Leave_Frame                    081.jpg  ...     099.jpg     100.jpg
# Angle_Thin_Film                   24.5  ...        25.5        25.5
# Total_Frames                       180  ...         145         144
# Passthrough                          0  ...           1           1
# H                                140.9  ...       233.9       242.9
# Angle_of_Drop_with_Normal        23.42  ...       24.49       24.51
# Velocity_at_Contact_Frame         4.65  ...         6.1        6.22
# X_Velocity_at_Contact_Frame      -0.09  ...       -0.11       -0.11
# Y_Velocity_at_Contact_Frame       4.65  ...         6.1        6.22
# Angle_at_Leave_Frame             -47.4  ...      -48.36       -53.5
# Velocity_at_Leave_Frame           2.59  ...        3.11        3.75
# X_Velocity_at_Leave_Frame         1.76  ...        2.07        2.23
# Y_Velocity_at_Leave_Frame         1.91  ...        2.32        3.01
#
#                                      19          20          21          22  \
# ID                            h18_short   h19_short   h20_short   h21_short
# Contact_Frame                   083.jpg     085.jpg     088.jpg     092.jpg
# Leave_Frame                     100.jpg     099.jpg     101.jpg     104.jpg
# Angle_Thin_Film                    29.5        29.5        29.0        29.0
# Total_Frames                        144         141         140         143
# Passthrough                           1           1           1           1
# H                                 264.3       282.2       298.2       322.5
# Angle_of_Drop_with_Normal         27.37       28.74       24.62       24.19
# Velocity_at_Contact_Frame          6.66        6.68        6.82         7.1
# X_Velocity_at_Contact_Frame       -0.25       -0.09       -0.52       -0.59
# Y_Velocity_at_Contact_Frame        6.65        6.68         6.8        7.08
# Angle_at_Leave_Frame             -60.87      -87.47      -79.51      -74.71
# Velocity_at_Leave_Frame            5.23        5.63        5.99        6.11
# X_Velocity_at_Leave_Frame          2.54        0.25        1.09        1.61
# Y_Velocity_at_Leave_Frame          4.56        5.62        5.89         5.9
#
#                                      23          24       25          26
# ID                            h22_short   h23_short      h24   h25_short
# Contact_Frame                   093.jpg     035.jpg  026.jpg     021.jpg
# Leave_Frame                     103.jpg     040.jpg  029.jpg     023.jpg
# Angle_Thin_Film                    29.5        18.5     20.5        19.0
# Total_Frames                        130          56       48          40
# Passthrough                           1           1        1           1
# H                                 340.8       391.8    486.4       463.7
# Angle_of_Drop_with_Normal          37.2       17.55    16.71        13.7
# Velocity_at_Contact_Frame          7.59       12.75     7.37        3.26
# X_Velocity_at_Contact_Frame        1.02       -0.21    -0.49        -0.3
# Y_Velocity_at_Contact_Frame        7.52       12.74     7.35        3.24
# Angle_at_Leave_Frame             -76.89      -89.01   -84.29       88.27
# Velocity_at_Leave_Frame            6.63       12.68    10.85        5.36
# X_Velocity_at_Leave_Frame           1.5        0.22     1.08       -0.16
# Y_Velocity_at_Leave_Frame          6.46       12.68     10.8        5.36
#
# [15 rows x 27 columns]

# %%
plt.rcdefaults()

# %%
sns.scatterplot(x='Velocity_at_Contact_Frame', y='Velocity_at_Leave_Frame', data=smooth_df, hue="Passthrough")
# Out:
# <AxesSubplot:xlabel='Velocity_at_Contact_Frame', ylabel='Velocity_at_Leave_Frame'>

# %%
sns.scatterplot(x='Velocity_at_Contact_Frame', y='Angle_at_Leave_Frame', data=smooth_df, hue="Passthrough")
# Out:
# <AxesSubplot:xlabel='Velocity_at_Contact_Frame', ylabel='Angle_at_Leave_Frame'>

# %%
sns.pairplot(smooth_df, hue='Passthrough');

# %%
sns.scatterplot(x='Velocity_at_Contact_Frame', y=smooth_df['H']**0.5, data=smooth_df, hue="Passthrough")
# Out:
# <AxesSubplot:xlabel='Velocity_at_Contact_Frame', ylabel='H'>
