# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
# from plotly.offline import init_notebook_mode
import seaborn as sns
# import cufflinks as cf
# init_notebook_mode(connected=True)
# cf.go_offline()
import warnings
warnings.filterwarnings('ignore')
plt.rcdefaults()
matplotlib.rcParams['figure.figsize'] = (10, 6)

# %% [markdown]
# # Loading The CSV Files

# %%
# smooth_df = pd.read_csv("results/info_on_smooth_data.csv")
raw_df = pd.read_csv("results/info_on_raw_data.csv")

# %% [markdown]
# # Analysis of Results

# %% [markdown]
# ## Results Using the Smoothed Data

# %%
# smooth_df = smooth_df[:-1]
raw_df = raw_df[:-1]

# %%
raw_df.T
# Out:
#                                    0        1        2        3       4   \
# ID                                 h1   h1_try       h2       h3      h4
# Contact_Frame                      73       73       94      263     116
# Leave_Frame                        85       85      113      285     136
# Angle_Thin_Film                  21.5     21.5     27.0     27.0    24.5
# Total_Frames                      219      219      300      370     282
# Passthrough                         0        0        0        1       0
# H                                74.0     70.0     81.0     86.0    99.0
# Angle_of_Drop_with_Normal       19.01     19.4    24.71     27.0   22.38
# Velocity_at_Contact_Frame        3.29     3.15     3.57     3.57    3.86
# X_Velocity_at_Contact_Frame     -0.14    -0.14    -0.14      0.0   -0.14
# Y_Velocity_at_Contact_Frame      3.29     3.14     3.57     3.57    3.86
# Angle_at_Leave_Frame            14.93    13.74    -45.0     -0.0   28.61
# ...

# %%
sns.scatterplot(x='Velocity_at_Contact_Frame_C', y='Velocity_at_Leave_Frame_C', data=raw_df, hue="Passthrough", alpha=0.7)
X = np.linspace(0, 12, 100)
# plt.plot(raw_df['Velocity_at_Contact_Frame'], raw_df['Velocity_at_Leave_Frame'], "r*")
sns.scatterplot(x='Velocity_at_Contact_Frame', y='Velocity_at_Leave_Frame', data=raw_df, hue="Passthrough", marker="*", s=100, alpha=0.7, legend=False)
plt.xlim(0, 13)
plt.ylim(0, 13)
plt.plot(X, X, "r", label="$x=y$")
plt.legend()
plt.xlabel("Speed at Contact Frame")
plt.ylabel("Speed at Leave Frame")
plt.title("Speed at Contact Frame vs Leave Frame")
plt.tight_layout()
plt.savefig("results/Speed_at_Contact_Frame_vs_Leave_Frame.png")

# %%
sns.scatterplot(x='Velocity_at_Contact_Frame_C', y='Angle_at_Leave_Frame_C', data=raw_df, hue="Passthrough", alpha=0.7)
sns.scatterplot(x='Velocity_at_Contact_Frame', y='Angle_at_Leave_Frame', data=raw_df, hue="Passthrough", marker="*", s=100, alpha=0.7, legend=False)
plt.ylim(-100, 100)
plt.xlim(0, 15)
plt.xlabel("Speed at Contact Frame")
plt.ylabel("Angle at Leave Frame")
plt.title("Speed at Contact Frame vs Angle at Leave Frame")
plt.tight_layout()
plt.savefig("results/Speed_at_Contact_Frame_vs_Angle_at_Leave_Frame.png")

# %%
cf = raw_df["Contact_Frame"].apply(lambda x : int(x))
lf = raw_df["Leave_Frame"].apply(lambda x : int(x))
diff = -cf+lf

# %%
plt.plot(raw_df["Velocity_at_Contact_Frame"],diff,  "o")

# %%
sns.scatterplot(y='Velocity_at_Contact_Frame', x=raw_df['H']**0.5, data=raw_df, hue="Passthrough")
# Out:
# <AxesSubplot:xlabel='H', ylabel='Velocity_at_Contact_Frame'>

# %%
raw_df.loc[15]
# Out:
# ID                                h14_short
# Contact_Frame                            76
# Leave_Frame                             100
# Angle_Thin_Film                        25.5
# Total_Frames                            148
# Passthrough                               1
# H                                     213.0
# Angle_of_Drop_with_Normal              24.1
# Velocity_at_Contact_Frame              5.86
# X_Velocity_at_Contact_Frame           -0.14
# Y_Velocity_at_Contact_Frame            5.86
# Angle_at_Leave_Frame                   5.19
# Velocity_at_Leave_Frame                3.16
# X_Velocity_at_Leave_Frame              3.14
# Y_Velocity_at_Leave_Frame             -0.29
# H_C                                   213.0
# Angle_at_Contact_Frame_C              25.78
# Velocity_at_Contact_Frame_C            6.36
# X_Velocity_at_Contact_Frame_C         -0.03
# Y_Velocity_at_Contact_Frame_C          6.36
# g_in_Region_I                       1082.28
# ...

# %%
raw_df.loc[13]
# Out:
# ID                                h12_short
# Contact_Frame                            20
# Leave_Frame                              42
# Angle_Thin_Film                        27.5
# Total_Frames                            100
# Passthrough                               0
# H                                      66.0
# Angle_of_Drop_with_Normal             25.95
# Velocity_at_Contact_Frame              5.29
# X_Velocity_at_Contact_Frame           -0.14
# Y_Velocity_at_Contact_Frame            5.29
# Angle_at_Leave_Frame                  17.65
# Velocity_at_Leave_Frame                 6.6
# X_Velocity_at_Leave_Frame              6.29
# Y_Velocity_at_Leave_Frame              -2.0
# H_C                                    66.0
# Angle_at_Contact_Frame_C              29.43
# Velocity_at_Contact_Frame_C             5.6
# X_Velocity_at_Contact_Frame_C         -0.19
# Y_Velocity_at_Contact_Frame_C          5.59
# g_in_Region_I                        876.31
# ...

# %%
sns.barplot(y="g_in_Region_I", x="ID", data=raw_df)
plt.ylim(-100, 1150)
plt.axhline(981, color="red", label="Standard g")
plt.legend()
plt.xticks(rotation=90);

# %%
sns.barplot(y="g_in_Region_III", x="ID", data=raw_df)
plt.ylim(-100, 1150)
plt.axhline(981, color="red", label="Standard g")
plt.legend()
plt.xticks(rotation=90);

# %%
sns.scatterplot(y=raw_df['Velocity_at_Leave_Frame_C'], x=raw_df['H']**0.5, data=raw_df, hue="Passthrough")
# Out:
# <AxesSubplot:xlabel='H', ylabel='Velocity_at_Leave_Frame_C'>

# %%
sns.scatterplot(y='Velocity_at_Leave_Frame', x=raw_df['H']**0.5, data=raw_df, hue="Passthrough")
# Out:
# <AxesSubplot:xlabel='H', ylabel='Velocity_at_Leave_Frame'>
