# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# from plotly.offline import init_notebook_mode
import seaborn as sns
# import cufflinks as cf
# init_notebook_mode(connected=True)
# cf.go_offline()
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Loading The CSV Files

# %%
smooth_df = pd.read_csv("results/info_on_smooth_data.csv")
raw_df = pd.read_csv("results/info_on_raw_data.csv")

# %% [markdown]
# # Analysis of Results

# %% [markdown]
# ## Results Using the Smoothed Data

# %%
smooth_df = smooth_df[:-1]
raw_df = raw_df[:-1]

# %%
smooth_df.T
# Out:
#                                 0        1      2      3      4          5   \
# ID                              h1   h1_try     h2     h3     h4   h5_short
# Contact_Frame                   73       73     94    263    116         59
# Leave_Frame                     85       85    113    285    136         77
# Angle_Thin_Film               21.5     21.5   27.0   27.0   24.5       24.5
# Total_Frames                   219      219    300    370    282        180
# Passthrough                      0        0      0      0      0          0
# H                             79.4     79.4   88.1   89.0   99.1      110.3
# Angle_of_Drop_with_Normal    32.48    32.48  26.94  27.33  17.54      19.67
# Velocity_at_Contact_Frame     3.45     3.45   3.76   3.95   3.83       4.04
# X_Velocity_at_Contact_Frame   0.66     0.66   -0.0   0.02  -0.46      -0.34
# Y_Velocity_at_Contact_Frame   3.38     3.38   3.76   3.95    3.8       4.03
# ...

# %%
plt.rcdefaults()

# %%
sns.scatterplot(x='Velocity_at_Contact_Frame', y='Velocity_at_Leave_Frame', data=smooth_df, hue="Passthrough")
X = np.linspace(0, 12, 100)
plt.plot(X, X)

# %%
plt.rcdefaults()

# %%
sns.scatterplot(x='Velocity_at_Contact_Frame', y='Angle_at_Leave_Frame', data=raw_df, hue="Passthrough")
plt.ylim(-100, 100);

# %%
cf = raw_df["Contact_Frame"].apply(lambda x : int(x.split(".")[0]))
lf = raw_df["Leave_Frame"].apply(lambda x : int(x.split(".")[0]))
diff = -cf+lf

# %%
plt.plot(raw_df["Velocity_at_Contact_Frame"],diff,  "o")

# %%
cf = smooth_df["Contact_Frame"].apply(lambda x : int(x.split(".")[0]))
lf = smooth_df["Leave_Frame"].apply(lambda x : int(x.split(".")[0]))
diff = -cf+lf
smooth_df["Diff"] = diff
sns.scatterplot(x="H", y="Diff", hue="Passthrough", data=smooth_df)
# Out:
# <AxesSubplot:xlabel='H', ylabel='Diff'>

# %%
raw_df["Angle_at_Contact_Frame"]

# %%
plt.rcdefaults()

# %%
sns.scatterplot(y='Velocity_at_Contact_Frame', x=smooth_df['H'], data=smooth_df, hue="Passthrough")
# Out:
# <AxesSubplot:xlabel='H', ylabel='Velocity_at_Contact_Frame'>

# %%
sns.scatterplot(y='Velocity_at_Contact_Frame', x=raw_df['H']**0.5, data=raw_df, hue="Passthrough")
# Out:
# <AxesSubplot:xlabel='H', ylabel='Velocity_at_Contact_Frame'>

# %%
sns.barplot(y="g", x="ID", data=raw_df)
plt.xticks(rotation=90);

# %%
sns.scatterplot(y=raw_df['Velocity_at_Leave_Frame_C'][2:], x=raw_df['H'][2:]**0.5, data=raw_df, hue="Passthrough")
# Out:
# <AxesSubplot:xlabel='H', ylabel='Velocity_at_Leave_Frame_C'>

# %%
sns.scatterplot(y='Velocity_at_Leave_Frame_C', x=raw_df['H']**0.5, data=raw_df, hue="Passthrough")
# Out:
# <AxesSubplot:xlabel='H', ylabel='Velocity_at_Leave_Frame_C'>
