# %%
from extract_center import CenterExtracter
import matplotlib.pyplot as plt
plt.rcdefaults()

# %%
c = CenterExtracter()

# %%
x = 150
y = 140
h=100
w=100
c.get_center("../data/Images1/67.jpg", x, y, h=h, w=w, strict=True)
# Out:
# (16, (866, 572))

# %%
c._show_image_(c.image, title="", binary=True, threshold=110)

# %%
c._show_image_(c.image)

# %%
c._show_image_(c.image_final)

# %%
x = 100
y = 50
h=100
w=100
c._show_image_(c.image[y:y+h, x:x+h]>120)

# %%
from life_saving_tools.files.notebook import Notebook

# %%
n = Notebook()

# %%
n.create_content("smoothing_curve.ipynb")
# Out:
# Converting the Notebook to HTML.
# Looking for the Headers and their positions.
# Getting correct order of the Headers.
# Creating the Contents.
# Content copied to clipboard.
